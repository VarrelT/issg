    "147b6770763b665687dabc0f569b13bc", "6d391d759cffe944b49999399dce79dd",
    "d72d91453e162d573a4c41bef45240d4", "991bdada86bc7e031d9c452adeec1913",
    "dd1175b61a59471563501417054cca73", "bd0f921e4fd749d07d92b93f8ae31635",
    "f11dd6b9b9bbc52f2efba463c5006ea0", "29dac160c97ea1185d9aa647e57e90c8",
    "a6ae7d3fbc9f6d8d4af9293c8d8881af", "93c5730fea4d6a7af9522a4798a04833",
    "28824d2c13bce195e9a23016fdcd9ddb", "81b5aea084bd12e84b7b6ed61f64d328",
    "bec37e85393395b2c90ecd108a9f3596", "5e0bbc2c39f1c308b15829599137c698",
    "d98b9e9740df4c1b108e2afaee0ae217", "5b24e41ce6579e8e12e59b7112b8f712",
    "1e1589df1e2a0648f54a83f7c8758733", "4cf41d88020b0717806e8de1740ac24a",
    "59181b21b9a8850df9d9a4a47b1edc3a", "9d91f9b1509fdb2ba2fb728cdc198705",
    "2fe079b62710eab333661d07f1c4c8b4", "72c2e8e125a0483fd2a357208e063202",
    "3a1274391b5a8bc9b09a3bb3ee3a349c", "13bf2516bdafe99c818f95088661e709",
    "3f92b78768ae2962bad800326cb92856", "8ca94a02a6376a5e3d4b1568a26c283e",
    "d886d7a8a54361dfaa9259009967906c", "98c38dc6c0cefd6b60efb84dfac615e3",
    "1a591397b14e1a057781e0191ce1e593", "fbf44276b71172ffbff088accdd67ae8",
    "68d709e54384a11bef53d726fb23df3f", "b1ff4929c6be5fe1771cff37a98928ec",
    "802beeaa739d588a411451d5ac3ce17f", "5d3d6b17433c8fc4fb7964e0b66aba37",
    "1cf9c727aa06a363e9a5397c9f48a6a9", "dbd98b51266c97240305238e54beab22",
    "9c951ceaa0fa19e21b2d7abedab5f625", "d5aa39d1907e6d78ec35f9369dcd0bdd",
    "0d9f70121d64428711697cb18fb19b01", "613a393a966f0f523c21f1485d790e9e"
]

# 2. Masukkan ke 'Set' untuk pencarian super cepat
target_hash_set = set(hash_list)

# 3. Buat dictionary untuk menyimpan hasil
#    Ini akan menyimpan (hash: pin) agar kita bisa memetakan kembali ke username
found_matches = {} # {hash: pin}

print(f"--- Memulai Pengecekan Brute-Force ---")
print(f"Jumlah Hash Target: {len(target_hash_set)}")
print(f"Jumlah PIN (Keyspace): 1,000,000")
print("Mencari...")

start_time = time.time()

# 4. Loop 1 juta kali (000000 s/d 999999)
# Ini adalah bagian inti dari algoritma Anda
for i in range(1000000):
    pin_attempt = str(i).zfill(6)

    # .encode('utf-8') diperlukan karena hash bekerja pada byte
    calculated_hash = hashlib.md5(pin_attempt.encode('utf-8')).hexdigest()

    # 5. Cek apakah hash ini ada di daftar target kita
    if calculated_hash in target_hash_set:
        print(f"DITEMUKAN! PIN: {pin_attempt} -> HASH: {calculated_hash}")
        found_matches[calculated_hash] = pin_attempt # Simpan sebagai {hash: pin}

        # Oprimalisasi: Berhenti lebih awal jika semua 100 hash sudah ditemukan
        if len(found_matches) == len(target_hash_set):
            print("Semua hash target telah ditemukan.")
            break

end_time = time.time()
total_time = end_time - start_time

print("\n--- Pengecekan Selesai ---")
print(f"Total waktu: {total_time:.4f} detik")
print(f"Total kecocokan ditemukan: {len(found_matches)} dari {len(target_hash_set)}")

# 6. Tampilkan semua yang berhasil dalam format tabel yang rapi
# Kita perlu data username dari PDF untuk ini
# Sumber:
user_hash_pairs = [
    ("user001", "cafc1e4642cda2652173a042f4f2b829"), ("user002", "239120bc9d0347b6e18c9939593cac8c"),
    ("user003", "bb0035d46ec2bf58ee7bacc7cf07e6c1"), ("user004", "0c67493c8ecbce10de00a1aafa5a0d58"),
    ("user005", "68bb5cca557ac400acb5b70dda479ef2"), ("user006", "68cb4c1da67caf7a74e73975bbee2240"),
    ("user007", "a82799f52c93a5c0c0a9bf53b2dd375f"), ("user008", "cf6a4598e43988471d0e721423083aa7"),
    ("user009", "466c426ce7d314d81bf6623fab1f6d42"), ("user010", "fc61a47c10ad53edf6a8f34c6c435f9c"),
    ("user011", "bde61ef2a35205c8d431873b15472cfe"), ("user012", "3f4d388d327d451f705ee9686c1254e6"),
    ("user013", "b518ffbda9a8765e60c431a261244e40"), ("user014", "1752e7a8e5056b28d2d20ae5294cf073"),
    ("user015", "726012e52150a8cdbd1c067868dc5531"), ("user016", "b762ba810efa7e45a126ff6f953101a9"),
    ("user017", "f5efbafdd42b4ca27d98eb6743d14241"), ("user018", "542ecb371f7bf19904b3a7be2ede505d"),
    ("user019", "b208aa5c6ff3e2607e8649cbefd154f1"), ("user020", "20c3d502b0efb043c5edb118915a3af1"),
    ("user021", "c6e6f0ccf8d3e7a9683a2ff0a2b9fb65"), ("user022", "774a9e3bb0268b3bd882e9782f5f0d7d"),
    ("user023", "e77e95a7e2c6ef6075a868e013abd73f"), ("user024", "04d049cb6d5d86b51f1424ccb6ae8e28"),
    ("user005", "68bb5cca557ac400acb5b70dda479ef2"), ("user006", "68cb4c1da67caf7a74e73975bbee2240"),
    ("user007", "a82799f52c93a5c0c0a9bf53b2dd375f"), ("user008", "cf6a4598e43988471d0e721423083aa7"),
    ("user009", "466c426ce7d314d81bf6623fab1f6d42"), ("user010", "fc61a47c10ad53edf6a8f34c6c435f9c"),
    ("user011", "bde61ef2a35205c8d431873b15472cfe"), ("user012", "3f4d388d327d451f705ee9686c1254e6"),
    ("user013", "b518ffbda9a8765e60c431a261244e40"), ("user014", "1752e7a8e5056b28d2d20ae5294cf073"),
    ("user015", "726012e52150a8cdbd1c067868dc5531"), ("user016", "b762ba810efa7e45a126ff6f953101a9"),
    ("user017", "f5efbafdd42b4ca27d98eb6743d14241"), ("user018", "542ecb371f7bf19904b3a7be2ede505d"),
    ("user019", "b208aa5c6ff3e2607e8649cbefd154f1"), ("user020", "20c3d502b0efb043c5edb118915a3af1"),
    ("user021", "c6e6f0ccf8d3e7a9683a2ff0a2b9fb65"), ("user022", "774a9e3bb0268b3bd882e9782f5f0d7d"),
    ("user075", "d98b9e9740df4c1b108e2afaee0ae217"), ("user076", "5b24e41ce6579e8e12e59b7112b8f712"),
    ("user077", "1e1589df1e2a0648f54a83f7c8758733"), ("user078", "4cf41d88020b0717806e8de1740ac24a"),
    ("user079", "59181b21b9a8850df9d9a4a47b1edc3a"), ("user080", "9d91f9b1509fdb2ba2fb728cdc198705"),
    ("user081", "2fe079b62710eab333661d07f1c4c8b4"), ("user082", "72c2e8e125a0483fd2a357208e063202"),
    ("user083", "3a1274391b5a8bc9b09a3bb3ee3a349c"), ("user084", "13bf2516bdafe99c818f95088661e709"),
    ("user085", "3f92b78768ae2962bad800326cb92856"), ("user086", "8ca94a02a6376a5e3d4b1568a26c283e"),
    ("user087", "d886d7a8a54361dfaa9259009967906c"), ("user088", "98c38dc6c0cefd6b60efb84dfac615e3"),
    ("user089", "1a591397b14e1a057781e0191ce1e593"), ("user090", "fbf44276b71172ffbff088accdd67ae8"),
    ("user091", "68d709e54384a11bef53d726fb23df3f"), ("user092", "b1ff4929c6be5fe1771cff37a98928ec"),
    ("user093", "802beeaa739d588a411451d5ac3ce17f"), ("user094", "5d3d6b17433c8fc4fb7964e0b66aba37"),
    ("user095", "1cf9c727aa06a363e9a5397c9f48a6a9"), ("user096", "dbd98b51266c97240305238e54beab22"),
    ("user097", "9c951ceaa0fa19e21b2d7abedab5f625"), ("user098", "d5aa39d1907e6d78ec35f9369dcd0bdd"),
    ("user099", "0d9f70121d64428711697cb18fb19b01"), ("user100", "613a393a966f0f523c21f1485d790e9e")
    ]

print("\n\n--- DAFTAR LENGKAP PIN YANG BERHASIL ---")
print(f"{'Username':<10} | {'PIN Ditemukan':<10} | {'Hash MD5':<34}")
print("-" * 58)

# Cocokkan hasil temuan dengan daftar username
for username, hash_value in user_hash_pairs:
    if hash_value in found_matches:
        pin = found_matches[hash_value]
        print(f"{username:<10} | {pin:<10} | {hash_value:<34}")
    else:
        # Ini seharusnya tidak terjadi jika semua 100 hash adalah PIN 6 digit
        print(f"{username:<10} | {'TIDAK DITEMUKAN':<10} | {hash_value:<34}")
# Out:
# --- Memulai Pengecekan Brute-Force ---
# Jumlah Hash Target: 100
# Jumlah PIN (Keyspace): 1,000,000
# Mencari...
# DITEMUKAN! PIN: 051270 -> HASH: 353a6276138d3ddc1b668753e4504aa3
# DITEMUKAN! PIN: 053606 -> HASH: 8ca94a02a6376a5e3d4b1568a26c283e
# DITEMUKAN! PIN: 139635 -> HASH: a82799f52c93a5c0c0a9bf53b2dd375f
# DITEMUKAN! PIN: 569498 -> HASH: 38a40e4ef059a6ffa3894157fda25b00
# DITEMUKAN! PIN: 684425 -> HASH: 823e2e9f3e150311c1273422d88ed8b4
# DITEMUKAN! PIN: 704440 -> HASH: 1e1589df1e2a0648f54a83f7c8758733
# DITEMUKAN! PIN: 722703 -> HASH: 3f4d388d327d451f705ee9686c1254e6
# DITEMUKAN! PIN: 950135 -> HASH: 68cb4c1da67caf7a74e73975bbee2240
    ("user061", "147b6770763b665687dabc0f569b13bc"), ("user062", "6d391d759cffe944b49999399dce79dd"),
    ("user063", "d72d91453e162d573a4c41bef45240d4"), ("user064", "991bdada86bc7e031d9c452adeec1913"),
    ("user065", "dd1175b61a59471563501417054cca73"), ("user066", "bd0f921e4fd749d07d92b93f8ae31635"),
    ("user067", "f11dd6b9b9bbc52f2efba463c5006ea0"), ("user068", "29dac160c97ea1185d9aa647e57e90c8"),
    ("user069", "a6ae7d3fbc9f6d8d4af9293c8d8881af"), ("user070", "93c5730fea4d6a7af9522a4798a04833"),
    ("user071", "28824d2c13bce195e9a23016fdcd9ddb"), ("user072", "81b5aea084bd12e84b7b6ed61f64d328"),
    ("user073", "bec37e85393395b2c90ecd108a9f3596"), ("user074", "5e0bbc2c39f1c308b15829599137c698"),
    ("user075", "d98b9e9740df4c1b108e2afaee0ae217"), ("user076", "5b24e41ce6579e8e12e59b7112b8f712"),
    ("user077", "1e1589df1e2a0648f54a83f7c8758733"), ("user078", "4cf41d88020b0717806e8de1740ac24a"),
    ("user079", "59181b21b9a8850df9d9a4a47b1edc3a"), ("user080", "9d91f9b1509fdb2ba2fb728cdc198705"),
    ("user081", "2fe079b62710eab333661d07f1c4c8b4"), ("user082", "72c2e8e125a0483fd2a357208e063202"),
    ("user083", "3a1274391b5a8bc9b09a3bb3ee3a349c"), ("user084", "13bf2516bdafe99c818f95088661e709"),
    ("user085", "3f92b78768ae2962bad800326cb92856"), ("user086", "8ca94a02a6376a5e3d4b1568a26c283e"),
    ("user087", "d886d7a8a54361dfaa9259009967906c"), ("user088", "98c38dc6c0cefd6b60efb84dfac615e3"),
    ("user089", "1a591397b14e1a057781e0191ce1e593"), ("user090", "fbf44276b71172ffbff088accdd67ae8"),
    ("user091", "68d709e54384a11bef53d726fb23df3f"), ("user092", "b1ff4929c6be5fe1771cff37a98928ec"),
    ("user093", "802beeaa739d588a411451d5ac3ce17f"), ("user094", "5d3d6b17433c8fc4fb7964e0b66aba37"),
    ("user095", "1cf9c727aa06a363e9a5397c9f48a6a9"), ("user096", "dbd98b51266c97240305238e54beab22"),
    ("user097", "9c951ceaa0fa19e21b2d7abedab5f625"), ("user098", "d5aa39d1907e6d78ec35f9369dcd0bdd"),
    ("user099", "0d9f70121d64428711697cb18fb19b01"), ("user100", "613a393a966f0f523c21f1485d790e9e")
]

# --- Pengaturan Serangan Multi-Salt ---
# Kita ubah SALT menjadi LIST (Daftar)
SALT_LIST = ["africa", "america", "europe", "asia", "australia"]

target_hash_set = set(hash_list)
found_matches = {}

print(f"--- Memulai Serangan Brute-Force dengan MULTI-SALT ---")
print(f"Daftar Salt: {SALT_LIST}")
print(f"Metode: 'SALT + PIN' dan 'PIN + SALT' untuk setiap salt")
print(f"Jumlah Hash Target: {len(target_hash_set)}")
print(f"Jumlah PIN (Keyspace): 1,000,000")
# Total kalkulasi sekarang = 1 juta * 5 salt * 2 mode = 10 juta hash
print(f"Total Kalkulasi Hash: {1000000 * len(SALT_LIST) * 2}")
print("Mencari...")

start_time = time.time()

# 3. Loop 1 juta kali (000000 s/d 999999)
for i in range(1000000):
    pin_attempt = str(i).zfill(6)

    # LOOP TAMBAHAN: Cek setiap salt di dalam daftar
    for salt in SALT_LIST:

        # --- Skenario 1: SALT + PIN ---
        attempt_prefix = salt + pin_attempt
        calculated_hash_prefix = hashlib.md5(attempt_prefix.encode('utf-8')).hexdigest()

        if calculated_hash_prefix in target_hash_set:
            if calculated_hash_prefix not in found_matches:
                print(f"DITEMUKAN! [{salt}] {attempt_prefix} -> HASH: {calculated_hash_prefix}")
                found_matches[calculated_hash_prefix] = attempt_prefix

        # --- Skenario 2: PIN + SALT ---
        attempt_suffix = pin_attempt + salt
        calculated_hash_suffix = hashlib.md5(attempt_suffix.encode('utf-8')).hexdigest()

        if calculated_hash_suffix in target_hash_set:
            if calculated_hash_suffix not in found_matches:
                print(f"DITEMUKAN! [{salt}] {attempt_suffix} -> HASH: {calculated_hash_suffix}")
                found_matches[calculated_hash_suffix] = attempt_suffix

    # Cek kondisi berhenti: Jika semua 100 hash ketemu, stop
    if len(found_matches) == len(target_hash_set):
        print("Semua hash target telah ditemukan.")
        break

end_time = time.time()
total_time = end_time - start_time

print("\n--- Pengecekan Selesai ---")
print(f"Total waktu: {total_time:.4f} detik")
print(f"Total kecocokan ditemukan: {len(found_matches)} dari {len(target_hash_set)}")

# 4. Tampilkan semua yang berhasil (atau gagal) dalam format tabel
print("\n\n--- DAFTAR LENGKAP HASIL ---")
print(f"{'Username':<10} | {'Kombinasi Ditemukan':<25} | {'Hash MD5':<34}")
print("-" * 75)

for username, hash_value in user_hash_pairs:
    if hash_value in found_matches:
        combination = found_matches[hash_value]
        print(f"{username:<10} | {combination:<25} | {hash_value:<34}")
    else:
        print(f"{username:<10} | {'TIDAK DITEMUKAN':<25} | {hash_value:<34}")
# Out:
# --- Memulai Serangan Brute-Force dengan MULTI-SALT ---
# Daftar Salt: ['africa', 'america', 'europe', 'asia', 'australia']
# Metode: 'SALT + PIN' dan 'PIN + SALT' untuk setiap salt
# Jumlah Hash Target: 100
# Jumlah PIN (Keyspace): 1,000,000
# Total Kalkulasi Hash: 10000000
# Mencari...
# DITEMUKAN! [africa] 003520africa -> HASH: 8f94435f16fe90cb19beb874103b43d7
# DITEMUKAN! [australia] australia028452 -> HASH: 3a1274391b5a8bc9b09a3bb3ee3a349c
# DITEMUKAN! [america] 179404america -> HASH: 726012e52150a8cdbd1c067868dc5531
# DITEMUKAN! [australia] australia185870 -> HASH: acc1d4579adb7ddb29255235c2ab23ee
# DITEMUKAN! [africa] 232152africa -> HASH: 2fe079b62710eab333661d07f1c4c8b4
# DITEMUKAN! [australia] 246514australia -> HASH: f84865023e95cb7a3ab33e7b048eba15
# DITEMUKAN! [europe] 262552europe -> HASH: 58ed44db1c17d29890b0399bac29e804
# DITEMUKAN! [australia] 277752australia -> HASH: b1ff4929c6be5fe1771cff37a98928ec
    ("user067", "f11dd6b9b9bbc52f2efba463c5006ea0"), ("user068", "29dac160c97ea1185d9aa647e57e90c8"),
    ("user069", "a6ae7d3fbc9f6d8d4af9293c8d8881af"), ("user070", "93c5730fea4d6a7af9522a4798a04833"),
    ("user071", "28824d2c13bce195e9a23016fdcd9ddb"), ("user072", "81b5aea084bd12e84b7b6ed61f64d328"),
    ("user073", "bec37e85393395b2c90ecd108a9f3596"), ("user074", "5e0bbc2c39f1c308b15829599137c698"),
    ("user075", "d98b9e9740df4c1b108e2afaee0ae217"), ("user076", "5b24e41ce6579e8e12e59b7112b8f712"),
    ("user077", "1e1589df1e2a0648f54a83f7c8758733"), ("user078", "4cf41d88020b0717806e8de1740ac24a"),
    ("user079", "59181b21b9a8850df9d9a4a47b1edc3a"), ("user080", "9d91f9b1509fdb2ba2fb728cdc198705"),
    ("user081", "2fe079b62710eab333661d07f1c4c8b4"), ("user082", "72c2e8e125a0483fd2a357208e063202"),
    ("user083", "3a1274391b5a8bc9b09a3bb3ee3a349c"), ("user084", "13bf2516bdafe99c818f95088661e709"),
    ("user085", "3f92b78768ae2962bad800326cb92856"), ("user086", "8ca94a02a6376a5e3d4b1568a26c283e"),
    ("user087", "d886d7a8a54361dfaa9259009967906c"), ("user088", "98c38dc6c0cefd6b60efb84dfac615e3"),
    ("user089", "1a591397b14e1a057781e0191ce1e593"), ("user090", "fbf44276b71172ffbff088accdd67ae8"),
    ("user091", "68d709e54384a11bef53d726fb23df3f"), ("user092", "b1ff4929c6be5fe1771cff37a98928ec"),
    ("user093", "802beeaa739d588a411451d5ac3ce17f"), ("user094", "5d3d6b17433c8fc4fb7964e0b66aba37"),
    ("user095", "1cf9c727aa06a363e9a5397c9f48a6a9"), ("user096", "dbd98b51266c97240305238e54beab22"),
    ("user097", "9c951ceaa0fa19e21b2d7abedab5f625"), ("user098", "d5aa39d1907e6d78ec35f9369dcd0bdd"),
    ("user099", "0d9f70121d64428711697cb18fb19b01"), ("user100", "613a393a966f0f523c21f1485d790e9e")
]

# ==========================================
# 3. KONFIGURASI DAN EKSEKUSI
# ==========================================
SALT_LIST = ["africa", "america", "europe", "asia", "australia"]
target_hash_set = set(hash_list)
found_matches = {}

print(f"--- Memulai Serangan Brute-Force SUPER KOMPREHENSIF ---")
print(f"Daftar Salt: {SALT_LIST}")
print(f"Target: {len(target_hash_set)} hash")
print("Mode: PREFIX (Salt+PIN) & SUFFIX (PIN+Salt)")
print("Level: Recursive Hashing KDF 2 s/d 5")
print("Mencari...")

start_time = time.time()

# Loop 000000 - 999999
for i in range(1000000):
    pin_attempt = str(i).zfill(6)

    # LOOP UNTUK SETIAP SALT (Africa, America, dst)
    for salt in SALT_LIST:

        # Siapkan 2 Skenario (Depan & Belakang)
        scenarios = [
            (salt + pin_attempt, "PREFIX"), # africa000000
            (pin_attempt + salt, "SUFFIX")  # 000000africa
        ]

        for base_string, mode_name in scenarios:
            # --- KDF Level 1 (Initial Hash) ---
            current_hash = hashlib.md5(base_string.encode('utf-8')).hexdigest()

            # --- Recursive Loop: KDF Level 2 sampai 5 ---
            for level in range(2, 6):
                # Hash dari hash sebelumnya
                current_hash = hashlib.md5(current_hash.encode('utf-8')).hexdigest()

                # Cek apakah cocok
                if current_hash in target_hash_set:
                    if current_hash not in found_matches:
                        kdf_label = f"KDF{level}"
                        # Menampilkan Salt yang dipakai agar jelas
                        print(f"DITEMUKAN! [Salt: {salt}] [{mode_name}] [{kdf_label}] PIN: {pin_attempt}")

                        found_matches[current_hash] = {
                            'pin': pin_attempt,
                            'salt': salt,
                            'mode': mode_name,
                            'level': kdf_label,
                            'base': base_string
                        }

    # Optimalisasi: Berhenti jika semua hash ketemu
    if len(found_matches) == len(target_hash_set):
        print("Semua hash target telah ditemukan.")
        break

end_time = time.time()
total_time = end_time - start_time

print("\n--- Pengecekan Selesai ---")
print(f"Total waktu: {total_time:.4f} detik")
print(f"Total kecocokan ditemukan: {len(found_matches)} dari {len(target_hash_set)}")

# ==========================================
# 4. TABEL HASIL
# ==========================================
print("\n\n--- DAFTAR LENGKAP HASIL ---")
# Header Tabel
print(f"{'Username':<10} | {'Salt':<10} | {'Mode & Level':<15} | {'Base Combo':<18} | {'Hash MD5':<34}")
print("-" * 95)

for username, hash_value in user_hash_pairs:
    if hash_value in found_matches:
        data = found_matches[hash_value]
        salt_used = data['salt']
        mode_level = f"{data['mode']} {data['level']}"
        base = data['base']
        print(f"{username:<10} | {salt_used:<10} | {mode_level:<15} | {base:<18} | {hash_value:<34}")
    else:
        print(f"{username:<10} | {'-':<10} | {'TIDAK DITEMUKAN':<15} | {'-':<18} | {hash_value:<34}")
# Out:
# --- Memulai Serangan Brute-Force SUPER KOMPREHENSIF ---
# Daftar Salt: ['africa', 'america', 'europe', 'asia', 'australia']
# Target: 100 hash
# Mode: PREFIX (Salt+PIN) & SUFFIX (PIN+Salt)
# Level: Recursive Hashing KDF 2 s/d 5
# Mencari...
# DITEMUKAN! [Salt: america] [SUFFIX] [KDF2] PIN: 041381
# DITEMUKAN! [Salt: asia] [SUFFIX] [KDF3] PIN: 075578
# DITEMUKAN! [Salt: europe] [SUFFIX] [KDF5] PIN: 083039
# DITEMUKAN! [Salt: america] [PREFIX] [KDF4] PIN: 093575
# DITEMUKAN! [Salt: america] [SUFFIX] [KDF2] PIN: 096970
# DITEMUKAN! [Salt: australia] [PREFIX] [KDF4] PIN: 106470
# DITEMUKAN! [Salt: america] [PREFIX] [KDF4] PIN: 112955
# DITEMUKAN! [Salt: europe] [SUFFIX] [KDF4] PIN: 131957
# DITEMUKAN! [Salt: asia] [SUFFIX] [KDF3] PIN: 192816
# DITEMUKAN! [Salt: africa] [PREFIX] [KDF3] PIN: 196300
# DITEMUKAN! [Salt: europe] [PREFIX] [KDF2] PIN: 212554
# DITEMUKAN! [Salt: europe] [PREFIX] [KDF5] PIN: 247747
# DITEMUKAN! [Salt: america] [PREFIX] [KDF2] PIN: 249136
# ...
